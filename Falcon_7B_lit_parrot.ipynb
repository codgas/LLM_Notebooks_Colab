# %%
# !git clone https://github.com/Lightning-AI/lit-parrot
# %cd lit-parrot
# !pip install --index-url https://download.pytorch.org/whl/nightly/cu118 --pre 'torch>=2.1.0dev'
# Out:
# Cloning into 'lit-parrot'...
# remote: Enumerating objects: 1472, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 1472 (delta 225), reused 179 (delta 168), pack-reused 1190
# Receiving objects: 100% (1472/1472), 489.91 KiB | 5.50 MiB/s, done.
# Resolving deltas: 100% (956/956), done.
# /content/lit-parrot
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu118, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 728.9 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 MB 8.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ...

# %%
# !pip install -r requirements.txt
# !python scripts/download.py | grep falcon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/Lightning-AI/lightning (to revision master) to /tmp/pip-install-q23bspgu/lightning_202ce1f090a741a0b8d7be152b8b9128
#   Running command git clone --filter=blob:none --quiet https://github.com/Lightning-AI/lightning /tmp/pip-install-q23bspgu/lightning_202ce1f090a741a0b8d7be152b8b9128
#   Resolved https://github.com/Lightning-AI/lightning to commit 67a14795cff77db7efec796d0ed5e9b7d0c3377d
#   Running command git submodule update --init --recursive -q
#   Encountered 31 file(s) that should have been pointers, but weren't:
#         .notebooks/course_UvA-DL/01-introduction-to-pytorch.ipynb
#         .notebooks/course_UvA-DL/02-activation-functions.ipynb
#         .notebooks/course_UvA-DL/03-initialization-and-optimization.ipynb
#         .notebooks/course_UvA-DL/04-inception-resnet-densenet.ipynb
# ...

# %%
# !pip install huggingface_hub

# !python scripts/download.py --repo_id tiiuae/falcon-7b

# !python scripts/convert_hf_checkpoint.py --checkpoint_dir checkpoints/tiiuae/falcon-7b
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 6.3 MB/s eta 0:00:00
# ...
# Fetching 12 files:   0% 0/12 [00:00<?, ?it/s]
# ...
#
# ...
#
# ...
#
# ...
#
# ...
# Fetching 12 files:   8% 1/12 [00:00<00:02,  5.15it/s]
#
# ...
#
# ...
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...
#
# ...

# %%
# !python generate/base.py --quantize llm.int8 --prompt "Hello, my name is" --checkpoint_dir checkpoints/tiiuae/falcon-7b/
# Out:
# Loading model 'checkpoints/tiiuae/falcon-7b/lit_model.pth' with {'block_size': 2048, 'vocab_size': 50254, 'padding_multiple': 512, 'padded_vocab_size': 65024, 'n_layer': 32, 'n_head': 71, 'n_embd': 4544, 'rotary_percentage': 1.0, 'parallel_residual': True, 'bias': False, 'n_query_groups': 1, 'shared_attention_norm': True}
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# Time to load model: 131.52 seconds.
# Global seed set to 1234
# Hello, my name is Jack.
# Some people think that dogs are like people. They see them as loyal, loving, and caring friends. I don't believe that's true. Dogs are animals. Animals are animals. I'm not a dog person.
# Time for inference 1: 6.93 sec total, 7.21 tokens/sec
# Memory used: 10.11 GB

# %%
# !python generate.py --quantize llm.int8 --prompt "Hello, my name is"
